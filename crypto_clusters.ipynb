# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# convert csv to pandas DataFrame
df = pd.read_csv('crypto_data.csv', index_col=0)
df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42           42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365          365Coin       X11       True   PoW/PoS              NaN
# 404          404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611        SixEleven   SHA-256       True       PoW              NaN
# 808              808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# locate cryptocurrencies that are trading and save as new DataFrame
df_trading = df.loc[df["IsTrading"]==True]
df_trading
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# remove "IsTrading" column
df_trading = df_trading.drop(columns="IsTrading")
df_trading
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 365       365Coin          X11   PoW/PoS              NaN      2300000000
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 611     SixEleven      SHA-256       PoW              NaN          611000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# SERO   Super Zero       Ethash       PoW              NaN      1000000000
# UOS           UOS      SHA-256      DPoI              NaN      1000000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# drop any row with NaN values
df_trading.dropna()
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# locate all cryptocurrencies that have been mined and save to new DataFrame
df_trading_mined = df_trading.loc[df_trading["TotalCoinsMined"]>0]
df_trading_mined
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# drop CoinName in preparation for machine learning
df_trading_mined = df_trading_mined.drop(columns="CoinName")
df_trading_mined
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
# dummify data
df_trading_mined_dummies = pd.get_dummies(df_trading_mined, columns=["Algorithm", "ProofType"])
df_trading_mined_dummies
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# ...               ...             ...                               ...
# ZEPH     2.000000e+09      2000000000                                 0
# GAP      1.493105e+07       250000000                                 0
# BDX      9.802226e+08      1400222610                                 0
# ZEN      7.296538e+06        21000000                                 0
# XBC      1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
# instantiate scaler
scaler = StandardScaler()

# %%
# scale data for machine learning
X_scaled = scaler.fit_transform(df_trading_mined_dummies)
X_scaled.shape
# Out:
# (532, 98)

# %%
X_scaled
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
# perform dimensionality reduction with PCA
pca = PCA(n_components=0.90)
pca_X_scaled = pca.fit_transform(X_scaled)
pca_X_scaled.shape
# Out:
# (532, 74)

# %%
# run t-SNE on PCA output
tsne = TSNE(learning_rate = 250)
tsne_X_scaled = tsne.fit_transform(pca_X_scaled)
tsne_X_scaled.shape
# Out:
# (532, 2)

# %%
tsne_X_scaled
# Out:
# array([[ 13.002436  , -11.047162  ],
#        [ 15.124714  , -18.036552  ],
#        [ 20.609547  , -23.862253  ],
#        ...,
#        [ 13.401596  ,  16.252148  ],
#        [ -4.133109  ,  20.209185  ],
#        [-11.427     ,  -0.50764835]], dtype=float32)

# %%
# Plot t-SNE output
X = tsne_X_scaled[:,0]
y = tsne_X_scaled[:,1]

plt.scatter(X, y)
plt.show()

# %% [markdown]
# Observation: There do seem to be at least 2 distinct clusters in the data.

# %%
# find the best k-values
inertia = []
k = list(range(1,11))

# find the k means cluster value
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(tsne_X_scaled)
    inertia.append(km.inertia_)

# %%
# Create an elbow plot
elbow_df = pd.DataFrame({'k': k, 'inertia': inertia})
elbow_df.plot.line(x='k', y='inertia')
plt.ylabel('Inertia')
plt.title('Elbow Plot')
plt.show()

# %% [markdown]
# Observation: the "elbow" of the k-value curve is at  k=5.

# %% [markdown]
# ##### Based on your findings, make a brief (1-2 sentences) recommendation to your clients. Can the cryptocurrencies be clustered together? If so, into how many clusters?

# %% [markdown]
# Based on the findings, the cryptocurrencies could be clustered together into 5 clusters, 2 of which are more distinct and the other 3 less obvious. I would recommend
